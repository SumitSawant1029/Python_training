# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("image.png")

plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# Q1

# %%
a = False
b=False
c=False

(a ^ b ^ c)
# Out:
# False

# %% [markdown]
# Q2

# %%
a = False
b=False
c=False

(a ^ b ^ c)
# Out:
# False

# %% [markdown]
# Q3

# %%
x=12
y=50
z=20

(x < z < y) or (y < z < x)
# Out:
# True

# %% [markdown]
# Q4

# %%
nums=[1,2,3,4,5,6]
k=0
for i in nums:
    for j in range(i,len(nums)):
        if(nums[i]==nums[j]):
            k=1
            
if(k==1):
    print("Set Consist of Duplicates")
else:
    print("Set Doesn't Consist of Duplicates")
# Out:
# Set Consist of Duplicates

# %%
(len(nums) == len(set(nums)))
# Out:
# len(set(nums))) was unexpected at this time.

# %% [markdown]
# Q5

# %%
nums = (10,20,30,40)
dict((x, x*x) for x in nums)
# Out:
# {10: 100, 20: 400, 30: 900, 40: 1600}

# %% [markdown]
# Q6

# %%
math = {'Alice','Bob','Charlie'}
science = {'Charlie','David','Eve'}
math ^ science
# Out:
# {'Alice', 'Bob', 'David', 'Eve'}

# %%
students = {'Alice':85,'Bob':72,'Charlie':90,'David':60}
max(students, key=students.get)
# Out:
# 'Charlie'

# %%
contacts = {'Alice':'1234','Bob':'5678','Charlie':'9999'}
('David' in contacts) and ('9999' in contacts.values())
# Out:
# False

# %%
t1 = (2,4,6)
t2 = (1,3,5)
tuple(a+b for a,b in zip(t1,t2))
# Out:
# (3, 7, 11)

# %%
data = {'Alice':[85,92], 'Bob':[72,88], 'Charlie':[90,90]}
any(100 in marks for marks in data.values())
# Out:
# False

# %%
a = [1,2,3]; b = a; c = [1,2,3]

a is b        
a == c       
2 in c

# %%
p, q, r = True, False, True
(p + q + r) >= 2
# Out:
# True

# %%
grades = {'Alice':85,'Bob':72,'Charlie':90,'David':60}
{k:v for k,v in grades.items() if v > 80}
# Out:
# {'Alice': 85, 'Charlie': 90}

# %%
set1 = {'a','b','c'}
set2 = {'b','c','d'}
bool(set1 & set2)
# Out:
# True

# %%
nums = [1,2,3,2,4,5,1,6,5]
set(nums)
# Out:
# {1, 2, 3, 4, 5, 6}
